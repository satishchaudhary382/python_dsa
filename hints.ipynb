# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
time = np.arange(0, 5, 0.1)
power_consumed = np.sin(time) + np.random.normal(0, 0.1, len(time))

# %%
fig1 = plt.figure(figsize=(20, 10))
plt.plot(time, power_consumed)
plt.title("Power consumed vs Time")
plt.xlabel("Time (days)")
plt.ylabel("Power consumed (watts)")
# Out:
# Text(0, 0.5, 'Power consumed (watts)')

# %%
st.pyplot(fig1)
# Out:
# 2024-05-07 16:55:41.545
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()
